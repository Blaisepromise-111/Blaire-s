# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Bless Promise Iwok**
#
#
# Data Analyst

# %% [markdown]
# _I am Interested in Data Science because I am curious about data and all the conclusions and hidden facts embedded in them. i want to be able to tell stories with data and satisfy my curiosity about certain things_

# %% [markdown]
# I want to run a simple code that gives me the sum of even numbers from 1 to 10

# %%
i=1
sum=0
while i<=10:
    if i%2==0:
        sum=sum+i
i+=1
print (sum)

# %%
list=[1,2,3,4,5]

# %% [markdown]
# print(list)

# %% [markdown]
# I was able to run my codes but i have no idea why the results won't be displayed. i hope i get this fixed because,
# - i would love to share my code
# - i am so happy i learnt so much
# ***
# Thank you Coursera for
# 1. teaching me so much
# 2. making it fun
# 3. creating great opportunities!
#
# ~~this is struckthrough!~~
#
# Here is an image
# ![8FAD3D6A-CD32-4554-A22C-A0BEB86B35A3-2-768x768.jpg](attachment:d072a2c1-3cef-48cc-bf94-5687976058d9.jpg)
# `this is the highlighted section`
# You can find instructions using this hyperlink: https://www.coursera.org/learn/open-source-tools-for-data-science/ungradedWidget/c1F5I/instructions-create-and-share-your-jupyter-notebook
#
# >there is a whole lot more to learn with python!

# %% [markdown]
# Heading forward to get my IBM reading Badge! See you there!
